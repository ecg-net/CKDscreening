# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
total = pd.read_csv('total results 40 bootstrap.csv')

# %%
total = total[~pd.isna(total.Mean)]

# %%
labels = total['Group Labels'].value_counts().to_dict()

# %%
data = []
text = []
for i in labels.keys():
    data.append(total[total['Group Labels']==i].Mean.dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -90)
plt.title("Total Results, all phenocodes")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts().to_dict()
data = []
text = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i].Mean.dropna().to_list())
    text.append(i)
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -45)
plt.title("Total Results, phenocodes with 100 positive examples")
plt.show()

# %%
temp
# Out:
#       Phenocode      Mean   Low  High  positives         Group Labels  \
# 0          8.00  0.630938  0.59  0.69      266.0  infectious diseases
# 2         38.10  0.763880  0.73  0.80      303.0  infectious diseases
# 3        320.00  0.830588  0.77  0.88      161.0         neurological
# 4        480.10  0.797460  0.78  0.82      621.0          respiratory
# 9          8.52  0.765730  0.75  0.79      683.0  infectious diseases
# ...         ...       ...   ...   ...        ...                  ...
# 1858     197.00  0.682147  0.65  0.72      395.0            neoplasms
# 1860     286.20  0.772671  0.76  0.79     2013.0        hematopoietic
# 1864     297.10  0.701530  0.65  0.74      339.0     mental disorders
# 1865     216.10  0.603343  0.52  0.65      141.0            neoplasms
# 1866      -1.00  0.621494  0.62  0.63    32898.0                Extra
#
#                                               Phenotype  qrs+_high      qrs+  \
# ...

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts().to_dict()
data = []
text = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['qrs+'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -90)
plt.title("QRS+ Results, phenocodes with 100 positive examples")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts().to_dict()
data = []
text = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['qrs-'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -90)
plt.title("QRS- Results, phenocodes with 100 positive examples")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts().to_dict()
data = []
text = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['beat'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -90)
plt.title("HeartBeat Results, phenocodes with 100 positive examples")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts().to_dict()
data = []
text = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['p+'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -90)
plt.title("P+ Results, phenocodes with 100 positive examples")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts().to_dict()
data = []
text = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['p-'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -90)
plt.title("P- Results, phenocodes with 100 positive examples")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts().to_dict()
data = []
text = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['t-'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -90)
plt.title("T- Results, phenocodes with 100 positive examples")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts().to_dict()
data = []
text = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['t+'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
plt.figure(figsize=(15,10))
plt.boxplot(data,labels = text)
plt.xticks(rotation = -90)
plt.title("T+ Results, phenocodes with 100 positive examples")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts()[:5].to_dict()
plt.figure(figsize=(15,10))
positions = np.array(range(0,5))
text = []

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['Mean'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
    print(temp['Group Labels'].value_counts())
x = plt.boxplot(data,labels = text,positions = positions,widths = 0.1)
set_box_color(x, 'black') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['qrs+'].dropna().to_list())
    print(temp['Group Labels'].value_counts())
y = plt.boxplot(data,positions = positions+0.15,widths = 0.1)
set_box_color(y, 'blue') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['qrs-'].dropna().to_list())
    print(temp['Group Labels'].value_counts())
y = plt.boxplot(data,positions = positions+0.3,widths = 0.1)
set_box_color(y, 'red') # colors are from http://colorbrewer2.org/


# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='black', label='Total')
plt.plot([], c='blue', label='QRS+')
plt.plot([], c='red', label='QRS-')
plt.legend()

plt.xticks(positions+0.15, text,rotation = -90)

plt.xticks()
plt.title("QRS Comparison phenocodes with 100 positive examples, top 5 most common groups")
plt.show()
# Out:
# circulatory system         108
# digestive                   64
# endocrine/metabolic         62
# respiratory                 52
# neoplasms                   50
# genitourinary               47
# neurological                40
# injuries & poisonings       39
# mental disorders            37
# symptoms                    30
# musculoskeletal             30
# Extra                       25
# dermatologic                24
# infectious diseases         23
# hematopoietic               22
# sense organs                14
# congenital anomalies         8
# pregnancy complications      1
# Name: Group Labels, dtype: int64
# circulatory system         108
# digestive                   64
# endocrine/metabolic         62
# respiratory                 52
# neoplasms                   50
# genitourinary               47
# neurological                40
# injuries & poisonings       39
# mental disorders            37
# symptoms                    30
# musculoskeletal             30
# ...

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts()[:5].to_dict()
plt.figure(figsize=(15,10))
positions = np.array(range(0,5))
text = []

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['Mean'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
x = plt.boxplot(data,labels = text,positions = positions,widths = 0.1)
set_box_color(x, 'black') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['p+'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.15,widths = 0.1)
set_box_color(y, 'blue') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['p-'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.3,widths = 0.1)
set_box_color(y, 'red') # colors are from http://colorbrewer2.org/


# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='black', label='Total')
plt.plot([], c='blue', label='P+')
plt.plot([], c='red', label='P-')
plt.legend()

plt.xticks(positions+0.15, text,rotation = -90)

plt.xticks()
plt.title("P Comparison phenocodes with 100 positive examples, top 5 most common groups")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts()[:5].to_dict()
plt.figure(figsize=(15,10))
positions = np.array(range(0,5))
text = []

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['Mean'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
x = plt.boxplot(data,labels = text,positions = positions,widths = 0.1)
set_box_color(x, 'black') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['t+'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.15,widths = 0.1)
set_box_color(y, 'blue') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['t-'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.3,widths = 0.1)
set_box_color(y, 'red') # colors are from http://colorbrewer2.org/


# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='black', label='Total')
plt.plot([], c='blue', label='T+')
plt.plot([], c='red', label='T-')
plt.legend()

plt.xticks(positions+0.15, text,rotation = -90)

plt.xticks()
plt.title("P Comparison phenocodes with 100 positive examples, top 5 most common groups")
plt.show()

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts()[:5].to_dict()
plt.figure(figsize=(15,10))
positions = np.array(range(0,5))
text = []

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['Mean'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
x = plt.boxplot(data,labels = text,positions = positions,widths = 0.1)
set_box_color(x, 'black') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['beat'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.15,widths = 0.1)
set_box_color(y, 'blue') # colors are from http://colorbrewer2.org/



# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='black', label='Total')
plt.plot([], c='blue', label='Heartbeat')
plt.legend()

plt.xticks(positions+0.075, text,rotation = -90)

plt.xticks()
plt.title("Heartbeat Comparison phenocodes with 100 positive examples, top 5 most common groups")
plt.show()

# %%
import numpy as np

# %%
temp = total[total.positives>100]
labels = temp['Group Labels'].value_counts()[:5].to_dict()
plt.figure(figsize=(15,10))
positions = np.array(range(0,10,2))
text = []

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['Mean'].dropna().to_list())
    text.append(i+'; count: '+str(labels[i]))
x = plt.boxplot(data,labels = text,positions = positions,widths = 0.15)
set_box_color(x, 'blue') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['qrs+'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.2,widths = 0.15)
set_box_color(y, 'red') # colors are from http://colorbrewer2.org/

#data = []
#for i in labels.keys():
#    data.append(temp[temp['Group Labels']==i]['qrs-'].dropna().to_list())
#y = plt.boxplot(data,positions = positions+0.3,widths = 0.1)
#set_box_color(y, 'lightblue') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['p+'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.4,widths = 0.15)
set_box_color(y, 'green') # colors are from http://colorbrewer2.org/

#data = []
#for i in labels.keys():
#    data.append(temp[temp['Group Labels']==i]['p-'].dropna().to_list())
#y = plt.boxplot(data,positions = positions+0.6,widths = 0.1)
#set_box_color(y, '#fdbb84') # colors are from http://colorbrewer2.org/


data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['t+'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.6,widths = 0.15)
set_box_color(y, 'chocolate') # colors are from http://colorbrewer2.org/

#data = []
#for i in labels.keys():
#    data.append(temp[temp['Group Labels']==i]['t-'].dropna().to_list())
#y = plt.boxplot(data,positions = positions+0.9,widths = 0.1)
#set_box_color(y, '#addd8e') # colors are from http://colorbrewer2.org/

data = []
for i in labels.keys():
    data.append(temp[temp['Group Labels']==i]['beat'].dropna().to_list())
y = plt.boxplot(data,positions = positions+0.8,widths = 0.15)
set_box_color(y, 'purple') # colors are from http://colorbrewer2.org/

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='black', label='Total')
plt.plot([], c='red', label='QRS+')
#plt.plot([], c='lightblue', label='QRS-')
plt.plot([], c='green', label='P+')
#plt.plot([], c='#fdbb84', label='P-')
plt.plot([], c='chocolate', label='T+')
#plt.plot([], c='#addd8e', label='T-')
plt.plot([], c='purple', label='Heartbeat')

plt.legend(loc=1)

plt.xticks(positions+0.525, text,rotation = -90)

plt.xticks()
plt.title("Phenocodes with 100 positive examples, top 5 most common groups")
plt.show()

# %%
1.05/2
# Out:
# 0.525
