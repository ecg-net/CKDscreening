# %%
import numpy as np

from paths import FilePaths
from tuningfunctions import get_data_loaders, get_criterion, Objective, run_trials
import models
import torch
import pandas as pd
import matplotlib.pyplot as plt
from ECG import EchoECG
from constants import MODEL_NAME, OPTIMIZERS, MAX_EPOCHS, METRIC, MIN_LR, MAX_LR, PATIENCE, SCHEDULER, STEP, GAMMA, PRUNER, NUM_TRIALS, DIRECTION
import wandb
from tqdm import tqdm
import sklearn

# %%
torch.cuda.empty_cache()

# %%
Train_csv = '/workspace/data/drives/Local_SSD/sdc/kidney_disease/one_hot_classifier/train.csv'
Val_csv = '/workspace/data/drives/Local_SSD/sdc/kidney_disease/one_hot_classifier/val.csv'
root = '/workspace/data/drives/Local_SSD/sdd/data/Remade with New Coefficents'
model_origin = 'RCRI_Net'
Project_name = 'multi_class_classification'
target='one_hot'

# %%
def collate_fn(batch):
    batch = list(filter(lambda x: x is not None, batch))
    return torch.utils.data.dataloader.default_collate(batch)

# %%
target_list = ['label']
torch.cuda.empty_cache()
root_list = {
    #'1 heartbeat': '/workspace/data/drives/Internal_SSD/sdd/data/Limited Datasets/2008-2020 EKG QRS Numpy',
    #'P Include': '/workspace/data/drives/Internal_SSD/sdd/data/Limited Datasets/P_include',
    #'P Exclude':'/workspace/data/drives/Internal_SSD/sdd/data/Limited Datasets/P_exclude',
    #'QRS Include':'/workspace/data/drives/Internal_SSD/sdd/data/Limited Datasets/QRS_include',
    #'QRS Exclude':'/workspace/data/drives/Internal_SSD/sdd/data/Limited Datasets/QRS_exclude',
    #'T Include':'/workspace/data/drives/Internal_SSD/sdb/data/Limited Datasets/T_include',
    #'T Exclude':'/workspace/data/drives/Internal_SSD/sdb/data/Limited Datasets/T_exclude'
}

for target in target_list:
    y_train=pd.read_csv(Train_csv)[target]
    criterion=torch.nn.BCELoss()
    print(y_train[0:5])
    
    train_ds = EchoECG(root = root, csv = Train_csv,model = model_origin,rolling = 0,downsample=1,target=target, one_lead=False)
    test_ds = EchoECG(root = root, csv = Val_csv,model = model_origin,rolling = 0,downsample=1,target=target, one_lead=False)
    bs = 2000
    train_dataloader = torch.utils.data.DataLoader(train_ds, batch_size=bs,num_workers=40,shuffle = True,drop_last=False,collate_fn=collate_fn)
    val_dataloader=torch.utils.data.DataLoader(test_ds, batch_size=bs,num_workers=40,drop_last=False,collate_fn=collate_fn)
    # train_dataloader, val_dataloader=get_data_loaders(X_train, X_test, y_train, y_test)


    ## Edit the capitalized general parameter inputs in constants.py. 
    # Model specific parameters are inputted in models.py
    objective=Objective(MODEL_NAME, criterion, train_dataloader, val_dataloader, OPTIMIZERS, 
                        0.0001, 0.0001,'roc_auc', 250, 100, SCHEDULER, STEP, 
                        0.98, Project_name,model_origin,stride = 8,
                        dilation = 2,channels = [32,16,24,40,80,112,192,320,1280,7],
                        category='classification', start_channels=12, multi_class=True)




    project_name = Project_name

    run_trials(objective, PRUNER, 1, DIRECTION, project_name)
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: label, dtype: int64
# missing 0.0
# Index(['Unnamed: 0', 'Filename', 'MRN', 'EKG_date', 'Gender', 'PatientAge',
#        'primary', 'ICD9_CD_LIST', 'ICD10_CD_LIST', 'label', 'one_hot'],
#       dtype='object')
# missing 0.0
# Index(['Unnamed: 0', 'Filename', 'MRN', 'EKG_date', 'Gender', 'PatientAge',
#        'primary', 'ICD9_CD_LIST', 'ICD10_CD_LIST', 'label', 'one_hot'],
#       dtype='object')
# self.exp 6
# wandb: Currently logged in as: mkaichristensen (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.7 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/mkaichristensen/multi_class_classification/runs/31t1zc8c" target="_blank">spring-yogurt-3</a></strong> to <a href="https://wandb.ai/mkaichristensen/multi_class_classification" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# [I 2021-12-03 21:56:36,203] A new study created in memory with name: no-name-ce108e76-8348-4986-bbe3-c950fab04168
# depth  [1, 2, 2, 3, 3, 3, 3]
# EffNet(
#   (stage1): Conv1d(12, 32, kernel_size=(3,), stride=(8,), padding=(1,), dilation=(2,))
#   (b0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (stage2): MBConv(
#     (stack): Sequential(
#       (s2): Bottleneck(
#         (conv1): Conv1d(32, 192, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(192, 192, kernel_size=(3,), stride=(2,), padding=(1,), groups=192)
#         (conv3): Conv1d(192, 16, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#     )
#     (bn): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (stage3): MBConv(
#     (stack): Sequential(
#       (s0): Bottleneck(
#         (conv1): Conv1d(16, 96, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(96, 96, kernel_size=(3,), stride=(1,), padding=(1,), groups=96)
#         (conv3): Conv1d(96, 16, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s3): Bottleneck(
#         (conv1): Conv1d(16, 96, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(96, 96, kernel_size=(3,), stride=(2,), padding=(1,), groups=96)
#         (conv3): Conv1d(96, 24, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#     )
#     (bn): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Pool): MaxPool1d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#   (stage4): MBConv(
#     (stack): Sequential(
#       (s0): Bottleneck(
#         (conv1): Conv1d(24, 144, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(144, 144, kernel_size=(3,), stride=(1,), padding=(1,), groups=144)
#         (conv3): Conv1d(144, 24, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s3): Bottleneck(
#         (conv1): Conv1d(24, 144, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(144, 144, kernel_size=(3,), stride=(2,), padding=(1,), groups=144)
#         (conv3): Conv1d(144, 40, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#     )
#     (bn): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (stage5): MBConv(
#     (stack): Sequential(
#       (s0): Bottleneck(
#         (conv1): Conv1d(40, 240, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(240, 240, kernel_size=(3,), stride=(1,), padding=(1,), groups=240)
#         (conv3): Conv1d(240, 40, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s1): Bottleneck(
#         (conv1): Conv1d(40, 240, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(240, 240, kernel_size=(3,), stride=(1,), padding=(1,), groups=240)
#         (conv3): Conv1d(240, 40, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s4): Bottleneck(
#         (conv1): Conv1d(40, 240, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(240, 240, kernel_size=(3,), stride=(2,), padding=(1,), groups=240)
#         (conv3): Conv1d(240, 80, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#     )
#     (bn): BatchNorm1d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (stage6): MBConv(
#     (stack): Sequential(
#       (s0): Bottleneck(
#         (conv1): Conv1d(80, 480, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(480, 480, kernel_size=(3,), stride=(1,), padding=(1,), groups=480)
#         (conv3): Conv1d(480, 80, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s1): Bottleneck(
#         (conv1): Conv1d(80, 480, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(480, 480, kernel_size=(3,), stride=(1,), padding=(1,), groups=480)
#         (conv3): Conv1d(480, 80, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s4): Bottleneck(
#         (conv1): Conv1d(80, 480, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(480, 480, kernel_size=(3,), stride=(2,), padding=(1,), groups=480)
#         (conv3): Conv1d(480, 112, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#     )
#     (bn): BatchNorm1d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (stage7): MBConv(
#     (stack): Sequential(
#       (s0): Bottleneck(
#         (conv1): Conv1d(112, 672, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(672, 672, kernel_size=(3,), stride=(1,), padding=(1,), groups=672)
#         (conv3): Conv1d(672, 112, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s1): Bottleneck(
#         (conv1): Conv1d(112, 672, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(672, 672, kernel_size=(3,), stride=(1,), padding=(1,), groups=672)
#         (conv3): Conv1d(672, 112, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s4): Bottleneck(
#         (conv1): Conv1d(112, 672, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(672, 672, kernel_size=(3,), stride=(2,), padding=(1,), groups=672)
#         (conv3): Conv1d(672, 192, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#     )
#     (bn): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (stage8): MBConv(
#     (stack): Sequential(
#       (s0): Bottleneck(
#         (conv1): Conv1d(192, 1152, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(1152, 1152, kernel_size=(3,), stride=(1,), padding=(1,), groups=1152)
#         (conv3): Conv1d(1152, 192, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s1): Bottleneck(
#         (conv1): Conv1d(192, 1152, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(1152, 1152, kernel_size=(3,), stride=(1,), padding=(1,), groups=1152)
#         (conv3): Conv1d(1152, 192, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#       (s4): Bottleneck(
#         (conv1): Conv1d(192, 1152, kernel_size=(1,), stride=(1,))
#         (conv2): Conv1d(1152, 1152, kernel_size=(3,), stride=(2,), padding=(1,), groups=1152)
#         (conv3): Conv1d(1152, 320, kernel_size=(1,), stride=(1,))
#         (b0): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b1): BatchNorm1d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (d): Dropout(p=0.5, inplace=False)
#         (act): ReLU6()
#       )
#     )
#     (bn): BatchNorm1d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (stage9): Conv1d(320, 1280, kernel_size=(1,), stride=(1,))
#   (AAP): AdaptiveAvgPool1d(output_size=1)
#   (act): ReLU()
#   (drop): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=1280, out_features=7, bias=True)
# )
# model: [1, 2, 2, 3, 3, 3, 3] channels: [32, 16, 24, 40, 80, 112, 192, 320, 1280, 7]2824191
# multi_class_classification/checkpointoptimizer: AdamW, lr: 0.0001,
# Current run is terminating due to exception: Using a target size (torch.Size([2000, 1])) that is different to the input size (torch.Size([2000, 7])) is deprecated. Please ensure they have the same size.
# Engine run is terminating due to exception: Using a target size (torch.Size([2000, 1])) that is different to the input size (torch.Size([2000, 7])) is deprecated. Please ensure they have the same size.
# [W 2021-12-03 21:57:49,684] Trial 0 failed because of the following error: ValueError('Using a target size (torch.Size([2000, 1])) that is different to the input size (torch.Size([2000, 7])) is deprecated. Please ensure they have the same size.')
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "/workspace/kai/phecode/Training/tuningfunctions.py", line 361, in __call__
#     trainer.run(self.train_loader, max_epochs=self.max_epochs)
#   File "/opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py", line 698, in run
#     return self._internal_run()
#   File "/opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py", line 771, in _internal_run
#     self._handle_exception(e)
#   File "/opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py", line 466, in _handle_exception
#     raise e
#   File "/opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py", line 741, in _internal_run
#     time_taken = self._run_once_on_dataset()
#   File "/opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py", line 845, in _run_once_on_dataset
#     self._handle_exception(e)
#   File "/opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py", line 466, in _handle_exception
#     raise e
#   File "/opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py", line 831, in _run_once_on_dataset
#     self.state.output = self._process_function(self, self.state.batch)
#   File "/opt/conda/lib/python3.8/site-packages/ignite/engine/__init__.py", line 103, in update
#     loss = loss_fn(y_pred, y)
#   File "/opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py", line 744, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/torch/nn/modules/loss.py", line 530, in forward
#     return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#   File "/opt/conda/lib/python3.8/site-packages/torch/nn/functional.py", line 2489, in binary_cross_entropy
#     raise ValueError("Using a target size ({}) that is different to the input size ({}) is deprecated. "
# ValueError: Using a target size (torch.Size([2000, 1])) that is different to the input size (torch.Size([2000, 7])) is deprecated. Please ensure they have the same size.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-7fefaa8425c8> in <module>
#      37     project_name = Project_name
#      38
# ---> 39     run_trials(objective, PRUNER, 1, DIRECTION, project_name)
#
# /workspace/kai/phecode/Training/tuningfunctions.py in run_trials(objective, pruner, num_trials, direction, project_name)
#     377     pruner = pruner
#     378     study = optuna.create_study(direction=direction, pruner=pruner)
# --> 379     study.optimize(objective, n_trials=num_trials, gc_after_trial=True,show_progress_bar=False)
#     380
#     381     print("Number of finished trials: ", len(study.trials))
#
# /opt/conda/lib/python3.8/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     398             )
#     399
# --> 400         _optimize(
#     401             study=self,
#     402             func=func,
#
# /opt/conda/lib/python3.8/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# /opt/conda/lib/python3.8/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# /opt/conda/lib/python3.8/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     262
#     263     if state == TrialState.FAIL and func_err is not None and not isinstance(func_err, catch):
# --> 264         raise func_err
#     265     return trial
#     266
#
# /opt/conda/lib/python3.8/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# /workspace/kai/phecode/Training/tuningfunctions.py in __call__(self, trial)
#     359
#     360         #run the trainer
# --> 361         trainer.run(self.train_loader, max_epochs=self.max_epochs)
#     362
#     363         #load the checkpoint with the best validation metric in the trial
#
# /opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py in run(self, data, max_epochs, epoch_length, seed)
#     696
#     697         self.state.dataloader = data
# --> 698         return self._internal_run()
#     699
#     700     @staticmethod
#
# /opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py in _internal_run(self)
#     769             self._dataloader_iter = None
#     770             self.logger.error(f"Engine run is terminating due to exception: {e}")
# --> 771             self._handle_exception(e)
#     772
#     773         self._dataloader_iter = None
#
# /opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py in _handle_exception(self, e)
#     464             self._fire_event(Events.EXCEPTION_RAISED, e)
#     465         else:
# --> 466             raise e
#     467
#     468     @property
#
# /opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py in _internal_run(self)
#     739                     self._setup_engine()
#     740
# --> 741                 time_taken = self._run_once_on_dataset()
#     742                 # time is available for handlers but must be update after fire
#     743                 self.state.times[Events.EPOCH_COMPLETED.name] = time_taken
#
# /opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py in _run_once_on_dataset(self)
#     843         except Exception as e:
#     844             self.logger.error(f"Current run is terminating due to exception: {e}")
# --> 845             self._handle_exception(e)
#     846
#     847         return time.time() - start_time
#
# /opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py in _handle_exception(self, e)
#     464             self._fire_event(Events.EXCEPTION_RAISED, e)
#     465         else:
# --> 466             raise e
#     467
#     468     @property
#
# /opt/conda/lib/python3.8/site-packages/ignite/engine/engine.py in _run_once_on_dataset(self)
#     829                 self.state.iteration += 1
#     830                 self._fire_event(Events.ITERATION_STARTED)
# --> 831                 self.state.output = self._process_function(self, self.state.batch)
#     832                 self._fire_event(Events.ITERATION_COMPLETED)
#     833
#
# /opt/conda/lib/python3.8/site-packages/ignite/engine/__init__.py in update(engine, batch)
#     101         x, y = prepare_batch(batch, device=device, non_blocking=non_blocking)
#     102         y_pred = model(x)
# --> 103         loss = loss_fn(y_pred, y)
#     104         if gradient_accumulation_steps > 1:
#     105             loss = loss / gradient_accumulation_steps
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     742             result = self._slow_forward(*input, **kwargs)
#     743         else:
# --> 744             result = self.forward(*input, **kwargs)
#     745         for hook in itertools.chain(
#     746                 _global_forward_hooks.values(),
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     528
#     529     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 530         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     531
#     532
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2487         reduction_enum = _Reduction.get_enum(reduction)
#    2488     if target.size() != input.size():
# -> 2489         raise ValueError("Using a target size ({}) that is different to the input size ({}) is deprecated. "
#    2490                          "Please ensure they have the same size.".format(target.size(), input.size()))
#    2491
#
# ValueError: Using a target size (torch.Size([2000, 1])) that is different to the input size (torch.Size([2000, 7])) is deprecated. Please ensure they have the same size.

# %% [markdown]
# !pip install pytorch-ignite optuna seaborn torchsummary tqdm==4.56.0 wandb ipywidgets opencv-python

# %%
# !nvidia-smi
# Out:
# Thu Nov  4 19:43:26 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.04    Driver Version: 455.23.04    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:01:00.0 Off |                  N/A |
# |  0%   58C    P0   105W / 350W |      0MiB / 24265MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:21:00.0 Off |                  N/A |
# |  0%   57C    P0    56W / 350W |      0MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !find /workspace/data/drives/Local_SSD/sdd/sdd/data -name 201691823_12-22-2017_23-42-14_SGM13200679PA22122017234214.npy
# Out:
# /workspace/data/drives/Local_SSD/sdd/sdd/data/All_EKG_data/201691823_12-22-2017_23-42-14_SGM13200679PA22122017234214.npy
